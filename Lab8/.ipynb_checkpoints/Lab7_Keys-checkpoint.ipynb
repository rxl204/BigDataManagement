# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  

import seaborn as sns
sns.set(style="whitegrid")

import fiona
import fiona.crs
import shapely
import rtree

import pandas as pd
import geopandas as gpd

# %%
shapefile = 'ZillowNeighborhoods-NY/ZillowNeighborhoods-NY.shp'
neighborhoods = gpd.read_file(shapefile).to_crs(fiona.crs.from_epsg(2263))

# with fiona.open() as fs:
#     print fs.crs
#     print fs.schema
#     for shape in fs:
#         print shape['properties']['NAME']
#         print shape['geometry']
#         break`

# %%
neighborhoods
# Out:
#     STATE    COUNTY                         CITY                     NAME  \
# 0      NY    Monroe                    Rochester          Ellwanger-Barry
# 1      NY  New York      New York City-Manhattan             West Village
# 2      NY     Kings       New York City-Brooklyn              Bensonhurst
# 3      NY      Erie                      Buffalo               South Park
# 4      NY  New York      New York City-Manhattan             East Village
# 5      NY    Albany                       Albany               Park South
# 6      NY  Onondaga                     Syracuse              Meadowbrook
# 7      NY    Queens         New York City-Queens               Auburndale
# 8      NY  Richmond  New York City-Staten Island                 Rosebank
# 9      NY  Onondaga                     Syracuse                 Downtown
# 10     NY  Onondaga                     Syracuse             Salt Springs
# 11     NY      Erie                      Buffalo           Starin Central
# 12     NY      Erie                      Buffalo              Cold Spring
# 13     NY  New York      New York City-Manhattan             Battery Park
# 14     NY    Monroe                    Rochester                Charlotte
# 15     NY     Bronx          New York City-Bronx             Throggs Neck
# 16     NY  New York      New York City-Manhattan            Carnegie Hill
# 17     NY    Queens         New York City-Queens            College Point
# 18     NY      Erie                      Buffalo                    Leroy
# 19     NY  Richmond  New York City-Staten Island          Mariners Harbor
# 20     NY    Albany                       Albany                Lancaster
# 21     NY  Richmond  New York City-Staten Island                Rossville
# 22     NY      Erie                      Buffalo               First Ward
# 23     NY    Monroe                    Rochester              East Avenue
# 24     NY    Queens         New York City-Queens  Douglastown-Little Neck
# 25     NY    Queens         New York City-Queens           Queens Village
# 26     NY     Bronx          New York City-Bronx              Morris Park
# 27     NY  New York      New York City-Manhattan                 Gramercy
# 28     NY     Bronx          New York City-Bronx               Baychester
# 29     NY    Queens         New York City-Queens           Middle Village
# ..    ...       ...                          ...                      ...
# 236    NY    Albany                       Albany                South End
# 237    NY    Monroe                    Rochester              Upper Falls
# 238    NY    Monroe                    Rochester               Browncroft
# 239    NY     Bronx          New York City-Bronx                  Tremont
# 240    NY    Queens         New York City-Queens             Howard Beach
# 241    NY  Richmond  New York City-Staten Island                  Clifton
# 242    NY  Onondaga                     Syracuse             South Valley
# 243    NY      Erie                      Buffalo                   Emslie
# 244    NY    Queens         New York City-Queens                   Utopia
# 245    NY     Bronx          New York City-Bronx              Parkchester
# 246    NY    Queens         New York City-Queens                  Bayside
# 247    NY  Richmond  New York City-Staten Island                Todt Hill
# 248    NY    Monroe                    Rochester               Lyell-Otis
# 249    NY     Bronx          New York City-Bronx              South Bronx
# 250    NY  New York      New York City-Manhattan         Garment District
# 251    NY  New York      New York City-Manhattan              East Harlem
# 252    NY      Erie                      Buffalo             Willert Park
# 253    NY      Erie                      Buffalo           Riverside Park
# 254    NY      Erie                      Buffalo           North Delaware
# 255    NY      Erie                      Buffalo               Kensington
# 256    NY      Erie                      Buffalo                    Allen
# 257    NY  Richmond  New York City-Staten Island    Westerleigh-Castleton
# 258    NY    Albany                       Albany  Upper Washington Avenue
# 259    NY    Albany                       Albany                Whitehall
# 260    NY    Albany                       Albany             Mansion Area
# 261    NY      Erie                      Buffalo              Masten Park
# 262    NY  Onondaga                     Syracuse               University
# 263    NY    Monroe                    Rochester      Atlantic-University
# 264    NY    Queens         New York City-Queens                   Corona
# 265    NY      Erie                      Buffalo                   Grider
#
#      REGIONID                                           geometry
# 0    343894.0  POLYGON ((19805.35711778826 1099961.053554856,...
# 1    270964.0  POLYGON ((980372.9910645633 205202.479966343, ...
# 2    193285.0  POLYGON ((978233.4712775955 159030.8800673813,...
# 3    270935.0  POLYGON ((-311815.6157876701 1012190.261676005...
# 4    270829.0  POLYGON ((987758.593831465 206590.8274387346, ...
# 5    342684.0  POLYGON ((1043646.140039243 907312.6265532071,...
# 6    274481.0  POLYGON ((426974.0696238258 1055557.477579877,...
# 7    270797.0  POLYGON ((1038529.848077805 208138.0234692516,...
# 8    197599.0  POLYGON ((967299.4152615013 160512.8338542489,...
# 9    273487.0  POLYGON ((410554.149589123 1058354.261591973, ...
# 10   275276.0  POLYGON ((427071.2897932617 1059543.36454923, ...
# 11   270940.0  POLYGON ((-312605.9801029053 1053362.726269616...
# 12   273299.0  POLYGON ((-316164.4388344725 1038400.652822263...
# 13   272869.0  POLYGON ((980805.2888988039 201424.7679190566,...
# 14   193771.0  POLYGON ((16456.55230043149 1136873.368575806,...
# 15   343210.0  POLYGON ((1027964.132181506 240860.8708758363,...
# 16   270810.0  POLYGON ((997796.8705163185 225625.870909223, ...
# 17   193942.0  (POLYGON ((1028227.937048782 229217.7403459254...
# 18   270869.0  POLYGON ((-313211.0025791806 1046749.856767292...
# 19   196213.0  POLYGON ((937375.7677230319 165612.3206927803,...
# 20   342699.0  POLYGON ((1038717.34948447 911720.6023973586, ...
# 21   197623.0  POLYGON ((918596.2530215158 140642.4394583431,...
# 22   270836.0  POLYGON ((-316627.0457670282 1020857.214068462...
# 23   343907.0  POLYGON ((23516.53557104736 1108139.17512679, ...
# 24   273478.0  POLYGON ((1052134.067433275 218489.4462776512,...
# 25   275115.0  POLYGON ((1059220.377878006 202163.9326447012,...
# 26   343212.0  POLYGON ((1017482.750115559 244416.6527186294,...
# 27   273860.0  POLYGON ((988480.984891533 212030.3978403088, ...
# 28   343223.0  POLYGON ((1024132.698337472 251817.1278443536,...
# 29   196338.0  POLYGON ((1018217.156762284 196125.2328634049,...
# ..        ...                                                ...
# 236  342693.0  POLYGON ((1047213.742213326 902223.3053685577,...
# 237  343905.0  POLYGON ((16380.08757555508 1115812.566728418,...
# 238  343892.0  POLYGON ((35215.02330374666 1105698.9818089, 3...
# 239  343215.0  POLYGON ((1008689.454930175 246760.4128270593,...
# 240  195489.0  (POLYGON ((1025970.972947196 174102.0575285197...
# 241  193879.0  POLYGON ((956984.2964182384 161719.2514929723,...
# 242  275463.0  POLYGON ((414169.2506244678 1040262.807292613,...
# 243  270833.0  POLYGON ((-314094.6299002445 1027583.74029622,...
# 244  276623.0  POLYGON ((1032394.42007526 200280.5473939437, ...
# 245  343211.0  POLYGON ((1019618.997396052 245925.4707769705,...
# 246  193200.0  (POLYGON ((1044684.581692875 228937.7522095744...
# 247  270950.0  POLYGON ((947919.4470172607 157430.3050963557,...
# 248  343880.0  POLYGON ((1302.89609801609 1118695.39881557, 1...
# 249  343217.0  POLYGON ((1004773.458534776 238437.0042645431,...
# 250  270842.0  POLYGON ((985562.4648847621 212466.9945654285,...
# 251  270828.0  POLYGON ((1002889.823442942 228237.2163923779,...
# 252  270966.0  POLYGON ((-316574.4377078324 1031008.857138549...
# 253  275206.0  POLYGON ((-330247.9472835152 1047222.694126116...
# 254  276474.0  POLYGON ((-319311.6001922252 1048380.400657643...
# 255  274175.0  POLYGON ((-301175.5201141572 1043415.854873773...
# 256  272750.0  POLYGON ((-321213.8112115394 1030645.694720803...
# 257  276006.0  POLYGON ((949479.744665871 167705.0954861072, ...
# 258  342697.0  POLYGON ((1038353.768390705 915035.5252185883,...
# 259  342688.0  POLYGON ((1035067.416296766 904336.0739108587,...
# 260  342685.0  POLYGON ((1048328.121277706 903058.0351020866,...
# 261  270883.0  POLYGON ((-318982.3249618637 1037936.525733864...
# 262  275808.0  POLYGON ((418956.9934353574 1052132.036502639,...
# 263  343903.0  POLYGON ((24398.42801437561 1110529.700135238,...
# 264  194032.0  POLYGON ((1020644.940651351 219755.9876883973,...
# 265  270849.0  POLYGON ((-307238.3654173653 1042701.724863636...
#
# [266 rows x 6 columns]

# %%
shapefile = 'ZillowNeighborhoods-NY/ZillowNeighborhoods-NY.shp'
neighborhoods = gpd.read_file(shapefile).to_crs(fiona.crs.from_epsg(2263))

index = rtree.Rtree()
for idx,geometry in enumerate(neighborhoods.geometry):
    index.insert(idx, geometry.bounds)

# %%
index.bounds
# Out:
# [-331110.02592820046,
#  119967.03773855612,
#  1067432.6651321745,
#  1150191.636787515]

# %%
import csv
import pyproj
import shapely.geometry as geom
proj = pyproj.Proj(init="epsg:2263", preserve_units=True)    

counts = {}
with open('green.csv', 'r') as fi:
    reader = csv.reader(fi)
    print(next(reader))
    for row in reader:
        pdt = row[0].split(' ')[1].split(':')[0]
        if pdt!='10':continue
        p = geom.Point(proj(float(row[3]), float(row[2])))
        match = None
        for idx in index.intersection((p.x, p.y, p.x, p.y)):
            if neighborhoods.geometry[idx].contains(p):
                match = idx
                break
        if match:
            counts[match] = counts.get(match, 0) + 1
# Out:
# ['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'pickup_latitude', 'pickup_longitude', 'dropoff_latitude', 'dropoff_longitude']

# %%
counts = counts.items()

# %%
countsPerNeighborhood = list(map(lambda x: (neighborhoods['NAME'][x[0]], x[1]), counts))
df = pd.DataFrame(countsPerNeighborhood).sort_values(1).set_index(0)
ax = df.plot(kind='barh', title='Green Taxi Trips per Neighborhood', 
             figsize=(8,24), fontsize=12, legend=False)
ax.yaxis.grid(False)

# %%
def processTrips(pid, records):
    if pid==0:
        next(records)
    counts = {}
    import rtree
    reader = csv.reader(records)
    proj = pyproj.Proj(init="epsg:2263", preserve_units=True)
    shapefile = 'ZillowNeighborhoods-NY/ZillowNeighborhoods-NY.shp'
    neighborhoods = gpd.read_file(shapefile).to_crs(fiona.crs.from_epsg(2263))
    index = rtree.Rtree()
    for idx,geometry in enumerate(neighborhoods.geometry):
        index.insert(idx, geometry.bounds)
    for row in reader:
        pdt = row[0].split(' ')[1].split(':')[0]
        if pdt!='10':
            continue
        p = geom.Point(proj(float(row[3]), float(row[2])))
        match = None
        for idx in index.intersection((p.x, p.y, p.x, p.y)):
            shape = neighborhoods.geometry[idx]
            if shape.contains(p):
                match = idx
                break
        if match:
            counts[match] = counts.get(match, 0) + 1
    return counts.items()
            
rdd = sc.textFile('green.csv')
counts = rdd.mapPartitionsWithIndex(processTrips) \
            .reduceByKey(lambda x,y: x+y) \
    .collect()
len(counts)
# Out:
# 57

# %%
def createIndex(shapefile):
    import rtree
    import fiona.crs
    import geopandas as gpd
    zones = gpd.read_file(shapefile).to_crs(fiona.crs.from_epsg(2263))
    index = rtree.Rtree()
    for idx,geometry in enumerate(neighborhoods.geometry):
        index.insert(idx, geometry.bounds)
    return (index, zones)

def findZone(p, index, zones):
    match = index.intersection((p.x, p.y, p.x, p.y))
    for idx in match:
        if zones.geometry[idx].contains(p):
            return idx
    return None

def processTrips(pid, records):
    import csv
    import pyproj
    import shapely.geometry as geom
    
    proj = pyproj.Proj(init="epsg:2263", preserve_units=True)    
    index, zones = createIndex('ZillowNeighborhoods-NY/ZillowNeighborhoods-NY.shp')    
    
    if pid==0:
        next(records)
    reader = csv.reader(records)
    counts = {}
    
    for row in reader:
        pdt = row[0].split(' ')[1].split(':')[0]
        if pdt!='10':
            continue
        p = geom.Point(proj(float(row[3]), float(row[2])))
        zone = findZone(p, index, zones)
        if zone:
            counts[zone] = counts.get(zone, 0) + 1
    return counts.items()
            
rdd = sc.textFile('green.csv')
counts = rdd.mapPartitionsWithIndex(processTrips) \
            .reduceByKey(lambda x,y: x+y) \
            .collect()
len(counts)
# Out:
# 57

# %%
countsPerNeighborhood = list(map(lambda x: (neighborhoods['NAME'][x[0]], x[1]), counts))
df = pd.DataFrame(countsPerNeighborhood).sort_values(1).set_index(0)
ax = df.plot(kind='barh', title='Green Taxi Trips per Neighborhood', figsize=(8,24), fontsize=12, legend=False)
ax.yaxis.grid(False)
